# %% [markdown]
# <center><img src='../img/clase11/intro.png' style='height:300px; float: center; margin: 0px 15px 15px 0px'></center>
#
# ### Visualización de proyectos de NLP
# #### NLP - Analítica Estratégica de Datos
# <br><b>Fundación Universitaria Konrad Lorenz</b>
# <br>Docente: Viviana Márquez [vivianam.penama@konradlorenz.edu.co](mailto:vivianama.penam@konradlorenz.edu.co)
# <br>Clase #11: Mayo 6, 2020

# %% [markdown]
# # Retroalimentación taller 9

# %% [markdown]
# ### Recordemos...
# <img src='../img/clase11/pipeline.png'>

# %% [markdown]
# ### 🚵‍♀️ Entramos en la recta final...
# <img src='../img/clase11/pipeline_class2021.png'>

# %% [markdown]
# ### 🚀 Hoy veremos...
#
# - Visualizaciones para proyectos de NLP 🚵‍♀️
#
# - La próxima clase: **Twitter** y Plotly

# %% [markdown]
# ### 🤔 ¿Por qué son importante las visualizaciones?
#
# <br>
# <img src='../img/clase11/pic2.png' style='height:500px; float: left; margin: 15px 15px 15px 15px'>
#
# - Parte esencial de un profesional en datos
# - Estamos un mundo lleno de datos
# - Queremos ganar conocimiento (ENTENDER)
# - Queremos hacer impacto (COMUNICAR)

# %% [markdown]
# ### 🤔 ¿Por qué son importante las visualizaciones?
#
# ### Para ENTENDER nuestros datos
#
# <br>
# <img src='../img/clase11/ss1.png' style='height:500px'>

# %% [markdown]
# ### 🤔 ¿Por qué son importante las visualizaciones?
#
# ### Para ENTENDER nuestros datos
#
# <br>
# <img src='../img/clase11/ss2.png' style='height:500px'>

# %% [markdown]
# ### 🤔 ¿Por qué son importante las visualizaciones?
#
# ### Para COMUNICAR nuestros datos
#
# <br>
# <img src='../img/clase11/ss3.png' style='height:500px'>

# %% [markdown]
# ### 🤔 ¿Por qué son importante las visualizaciones?
#
# ### Para COMUNICAR nuestros datos
#
# <br>
# <img src='../img/clase11/ss4b.png' style='height:500px'>

# %% [markdown]
# ### ⚙️ Herramientas más populares en el mercado para hacer visualizaciones
#
# <br>
# <img src='../img/clase11/herramientas2.png' style='height:500px'>

# %% [markdown]
# ### ⚙️ Herramientas más populares en el mercado para hacer visualizaciones
#
# <br>
# <img src='../img/clase11/info.png' style='height:500px'>

# %% [markdown]
# ### ⚙️ Herramientas más populares en el mercado para hacer visualizaciones
#
# <br><br>
# <img src='../img/clase11/python.jpg' style='height:300px; float: left; margin: 45px 45px 45px 45px'>
#
# - Matplotlib
# - Seaborn
# - Plotly
# - Bokeh
# - Altair
# - Geoplotlib

# %% [markdown]
# # 😉 Tips generales para las visualizaciones
# Source: HubSpot + Visage

# %% [markdown]
# <img src='../img/clase11/tip1a.png'>

# %% [markdown]
# <img src='../img/clase11/tip2.png'>

# %% [markdown]
# <img src='../img/clase11/tip4.png'>

# %% [markdown]
# <img src='../img/clase11/tip5.png'>

# %% [markdown]
# # 😉 Tips generales para las visualizaciones
#
# - Piensa en la audiencia:
#     - ¿Cómo van a crear tus datos objetivos realizables?
#     - ¿Su público tiene el software necesario?
#
# - Menos es más
#     - En un mundo lleno de datos, queremos ENTENDER y COMUNICAR

# %% [markdown]
# ### 🙋‍♀️ ¿Qué se dicen mis estudiantes?
#
# <br>
# <center><img src='../img/clase11/estudiantes.jpeg' style='height:250px; float: center; margin: 0px 15px 15px 0px'></center>
#
# <table>
#  <tr>
#     <td><b style="font-size:35px">Herramientas</b></td>
#     <td><b style="font-size:35px">Gráficas</b></td>
#  </tr>
#  <tr>
#     <td>Herramientas Libres</td>
#     <td>Mapas</td>
#  </tr>
# <tr>
#     <td> </td>
#     <td>Gráficos dinámicos</td>
#  </tr>
# <tr>
#     <td> </td>
#     <td>Nube de palabras</td>
#  </tr>
# <tr>
#     <td> </td>
#     <td>Bigotes y cajas</td>
#  </tr>
# </table>

# %% [markdown]
# # 1. Jupyter Notebook & GitHub Pages
#
# - Jupyter Notebook te da la posibilidad de crear presentaciones con el plugging RISE
#     - `pip install RISE`
#     - `jupyter-nbextension install rise --py --sys-prefix`
#     - `jupyter nbextension enable rise --py --sys-prefix`
# <br><br>
# - GitHub pages te da la opción de publicar presentaciones, páginas web, etc.
#     - Instrucciones para subir presentaciones [aquí](https://medium.com/@alejatorresm/presentaciones-usando-jupyter-notebook-6cb20434fbe9) --- Ejemplo [aquí](https://alejandratm.github.io/Jupyter-Slides-Hola-Mundo/Presentacion-HW/Hello-litle-World.slides.html#/)
#     - Ejemplo página web [aquí](http://vivianamarquez.com/) --- Plantilla [aquí](https://github.com/daattali/beautiful-jekyll)
#     <br><br>
# - Visualizador de Notebooks `https://nbviewer.jupyter.org/github/` --- Ejemplo

# %% [markdown]
# ### Presentaciones con Jupyter Notebook
#
# 1. Instalar RISE
# <br><br>
# <center>
#     <img src='../img/clase11/rise1.png' style='width:1300px; float: center; margin: 0px 15px 15px 0px'>
#     <img src='../img/clase11/rise2.png' style='width:1300px; float: center; margin: 0px 15px 15px 0px'>
#     <img src='../img/clase11/rise3.png' style='width:1300px; float: center; margin: 0px 15px 15px 0px'>
# </center>

# %% [markdown]
# ### Presentaciones con Jupyter Notebook
#
# 2. Botón de presentación debe aparecer
# <br><br>
# <center>
#     <img src='../img/clase11/rise4.png' style='width:600px; float: center; margin: 0px 15px 15px 0px'>
# </center>
#
# 2. Seleccionar Markdown
# <br><br>
# <center>
#     <img src='../img/clase11/rise5.png' style='width:600px; float: center; margin: 0px 15px 15px 0px'>
# </center>

# %% [markdown]
# ### Presentaciones con Jupyter Notebook
#
# 4. Modo presentación
# <br><br>
# <center>
#     <img src='../img/clase11/rise6.png' style='width:600px; float: center; margin: 0px 15px 15px 0px'>
#
#     <img src='../img/clase11/rise7.png' style='width:600px; float: center; margin: 0px 15px 15px 0px'>
# </center>

# %% [markdown]
# ### Presentaciones con Jupyter Notebook
#
# 5. Exportar
# <br><br>
# <center>
#     <img src='../img/clase11/rise8.png' style='width:600px; float: center; margin: 0px 15px 15px 0px'>
# </center>
#
# 6. Los Jupyter Notebooks pueden ser usados para otros lenguajes de programación

# %% [markdown]
# #### Carguemos los datos con los que vamos a trabajar

# %%
import pandas as pd

data = pd.read_csv("../archivos/dia_madre.csv")
data.head()
# Out:
#                                                tweet                 date  \
# 0  #ParoNacional6M marica todos en el centro y su...  2021-05-06 16:44:19
# 1  En la CCCE creemos que un día no es suficiente...  2021-05-06 16:28:48
# 2  @Compensar_info buen día ya realicé la actuali...  2021-05-06 16:16:40
# 3  Gordo, te acuerdas cuando un país se movilizó ...  2021-05-06 16:12:20
# 4  @Annge_myg Creería que quiere aprovechar el fi...  2021-05-06 15:49:45
#
#      city       lat        lon
# 0  Bogotá  4.649178 -74.062827
# 1  Bogotá  4.649178 -74.062827
# 2  Bogotá  4.649178 -74.062827
# 3  Bogotá  4.649178 -74.062827
# 4  Bogotá  4.649178 -74.062827

# %% [markdown]
# # 2. Nube de palabras
#
# `pip install wordcloud`
#
# `conda install -c anaconda pillow`

# %%
import numpy as np

from wordcloud import WordCloud, ImageColorGenerator

from nltk.corpus import stopwords
stopwords = stopwords.words("spanish")

import matplotlib.pyplot as plt
import PIL.Image
from IPython.display import display

# %%
palabras = data.tweet.str.cat(sep=" ")
wordcloud = WordCloud().generate(palabras)

plt.imshow(wordcloud)
plt.show()

# %%
import re 

# stopwords.append("https")
# stopwords.append("co")

stopwords.extend(["https", "co", "día", "dia", "madres", "madre"])

def pre_procesado(texto):
    texto = texto.lower()
    texto = re.sub(r"[\W\d_]+", " ", texto)
    texto = [palabra for palabra in texto.split() if palabra not in stopwords]
    texto = " ".join(texto)
    return texto

data['pp'] = data.tweet.apply(lambda texto: pre_procesado(texto))

data.head()
# Out:
#                                                tweet                 date  \
# 0  #ParoNacional6M marica todos en el centro y su...  2021-05-06 16:44:19
# 1  En la CCCE creemos que un día no es suficiente...  2021-05-06 16:28:48
# 2  @Compensar_info buen día ya realicé la actuali...  2021-05-06 16:16:40
# 3  Gordo, te acuerdas cuando un país se movilizó ...  2021-05-06 16:12:20
# 4  @Annge_myg Creería que quiere aprovechar el fi...  2021-05-06 15:49:45
#
#      city       lat        lon  \
# 0  Bogotá  4.649178 -74.062827
# 1  Bogotá  4.649178 -74.062827
# 2  Bogotá  4.649178 -74.062827
# 3  Bogotá  4.649178 -74.062827
# 4  Bogotá  4.649178 -74.062827
#
#                                                   pp
# 0  paronacional m marica centro sur haciendo paro...
# 1  ccce creemos suficiente celebrar mamá queremos...
# 2  compensar info buen realicé actualización dato...
# 3  gordo acuerdas país movilizó muerte violenta s...
# 4  annge myg creería quiere aprovechar fin semana...

# %%
# Más en https://www.datacamp.com/community/tutorials/wordcloud-python
palabras = data.pp.str.cat(sep=" ")
wordcloud = WordCloud(width=800, height=400,
                      max_font_size=150, max_words=100,
                      background_color="white", colormap="spring",
                      stopwords=stopwords, collocations=True).generate(palabras) # https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
img = PIL.Image.open("../img/clase11/flower2.png")
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1182x1108 at 0x7FBEAD27C7D0>

# %%
mask = np.array(img)
mask
# Out:
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
# ...

# %%
# Más en https://www.datacamp.com/community/tutorials/wordcloud-python
palabras = data.pp.str.cat(sep=" ")
wordcloud = WordCloud(width=800, height=400,
                      max_font_size=150, max_words=100,
                      background_color="white", colormap="spring",
                      stopwords=stopwords, collocations=True,
                      mask=mask, contour_width=1, contour_color='pink').generate(palabras) # https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

wordcloud.to_file("nlp_flor.png")

plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
# Más en https://www.datacamp.com/community/tutorials/wordcloud-python
palabras = data.pp.str.cat(sep=" ")
wordcloud = WordCloud(width=800, height=400,
                      max_font_size=150, max_words=100,
                      background_color="white", colormap="spring",
                      stopwords=stopwords, collocations=True,
                      mask=mask, contour_width=1, contour_color='pink').generate(palabras) # https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

image_colors=ImageColorGenerator(mask)

wordcloud.to_file("nlp_flor.png")

plt.figure(figsize=(10,8))
plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# # 3. Tableau
#
# Link de descarga: https://public.tableau.com/en-us/s/download
#
# - Programa para crear tableros (dashboards) interactivos
# - Tiene varios productos:
#     - Tableau Desktop (Profesional)
#     - Tableau Server
#     - Tableau Prep (flujo de datos)
#     - Tableau Public (versión gratis) [Link](https://public.tableau.com/profile/viviana.m.rquez#!/?newProfile=&activeTab=0)
#
# - Se puede conectar Python y R a Tableau [Link1](https://vivianamarquez.medium.com/python-tableau-desktop-101-b1281d9f7404) [Link2](https://vivianamarquez.medium.com/tableau-prep-python-101-c6a2b5292233)

# %% [markdown]
# #### Gráficos que vamos a hacer:
# - Nube de palabras
# - Mapa de árbol
# - Mapa

# %% [markdown]
# #### Vamos a preparar los datos

# %%
data.city.value_counts()
# Out:
# Villavicencio            100
# Santa Marta              100
# Barranquilla             100
# Cali                     100
# Bogotá                   100
# Cartagena                100
# Neiva                    100
# Medellín                  92
# Armenia                   85
# Pereira                   81
# Manizales                 36
# Ibagué                    35
# Valledupar                29
# Bucaramanga               27
# Cúcuta                    20
# Tunja                     18
# Ríohacha                  18
# Sincelejo                 16
# Montería                  12
# Yopal                     11
# Arauca                     7
# Pasto                      4
# Quibdó                     2
# Puerto Carreño             2
# Florencia                  2
# Mocoa                      2
# San José del Guaviare      2
# Leticia                    1
# Popayán                    1
# Name: city, dtype: int64

# %%
# Nube de palabras & Mapa de árbol

ciudad1 = "Cali"
ciudad2 = "Armenia"

data1 = data[data.city==ciudad1]
data2 = data[data.city==ciudad2]

palabras1 = data1.pp.str.cat(sep=" ")
palabras2 = data2.pp.str.cat(sep=" ")

wordcloud1 = WordCloud().generate(palabras1).words_
wordcloud2 = WordCloud().generate(palabras2).words_

temp1 = pd.DataFrame.from_dict(wordcloud1, orient='index').reset_index()
temp1.columns = ['palabra', 'peso']
temp1['ciudad'] = ciudad1

temp2 = pd.DataFrame.from_dict(wordcloud2, orient='index').reset_index()
temp2.columns = ['palabra', 'peso']
temp2['ciudad'] = ciudad2

data_nube = pd.concat([temp1, temp2])

data_nube.to_csv("nube.csv", index=False)

# %%
# Mapa

data['contador_palabras'] = data.pp.apply(lambda texto: len(texto.split()))
data[['city', 'lat', 'lon', 'contador_palabras']].to_csv("mapa.csv", index=False)

# %% [markdown]
# # Resultado:
# LINK
#
# https://public.tableau.com/views/EjemploClase2021-I/Dashboard1?:language=en&:display_count=y&publish=yes&:origin=viz_share_link

# %% [markdown]
# # 4. La trifecta: Plotly, Dash y Flask
#
# - **Plotly**: Herramienta de visualización interactiva. Funciona con Python, R, Julia, etc.
# [Recurso](https://plotly.com/python/plotly-fundamentals/)
#
# - **Dash**: Entorno de trabajo para construir aplicaciones web (usa Flask y Plotly)
# [Recurso](https://www.datacamp.com/community/tutorials/learn-build-dash-python). [Ejemplo](https://msds2019.herokuapp.com/)
#
# - **Flask**: Entorno de trabajo para construir aplicaciones web para Python
# [Recurso](https://flask.palletsprojects.com/en/1.1.x/tutorial/)
#
# `pip install plotly`

# %% [markdown]
# # ¡Tiempo de taller!
#
# <center>
# <img src='../img/Taller.gif'>

# %% [markdown]
# **Taller #10:** Realizar una nube de palabras (Python ó Tableau, subir al aula virtual cualquiera de los dos links) con cualquier texto (excepto el que usamos en la clase de hoy)
#
# **Fecha de entrega:** Mayo 13, 2021. (Antes del inicio de la próxima clase)

# %% [markdown]
# <center>
# <img src='../img/fin.png' style='height:300px; float: center; margin: 0px 15px 15px 0px'>
#
# ### Próxima clase: NLP y Redes Sociales
